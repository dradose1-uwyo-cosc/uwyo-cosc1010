# %% [markdown]
# <h1 style="text-align: center;">Working With Lists: Numerical Lists and Range</h1>
# <h2 style="text-align: center;">Adapted from "Python Crash Course" By Eric Matthes</h2>

# %% [markdown]
# * Last video we learned how to loop through lists
# * This time we'll look at numerical lists, the range() function, and list comprehensions
# * These are tools you'll use constantly whenever working with numbers

# %% [markdown]
# # Why this matters
# ---
# A huge amount of programming involves working with sequences of numbers
# * Test scores, temperatures over time, pixel values in an image
#
# `range()` and the tools around it let Python handle counting automatically so you can focus on what you actually want to do with the numbers
#
# **Python is counting for you so you don't have to**

# %% [markdown]
# * Many reasons exist to store a set of numbers
# * For example, keeping track of images in a grid
# * In data visualization you'll almost always work with sets of numbers
# 	* Temperatures
# 	* Distances
# 	* Population sizes
# 	* Latitude and Longitude
# * Lists are ideal for storing sets of numbers
# * Python provides a variety of tools to help you work efficiently with lists and numbers
# * Once you understand these tools your code will work well even with lists containing millions of items

# %% [markdown]
# # The `range()` Function
# ---
# * `range()` makes it easy to generate a series of numbers
# * Note: it looks like it should print `1, 2, 3, 4, 5`
#     * but it only prints `1` through `4`
# * This is the *off-by-one* nature of programming
#     * `range()` stops **before** the upper bound
# * If your output is different than expected when using `range()`, try checking your bounds!

# %% [markdown]
# * Python's `range()` function makes it easy to generate a series of numbers
# * `range()` can be used to print a series of numbers among other uses
# * Note the code looks like it should print `1, 2, 3, 4, 5`
# * However, it only prints `1-4`
# * This is a result of the *off-by-one* nature of a lot of programming
# * The `range()` function starts at the lower bound given and stops when it reaches the upper
# * As it reaches the upper bound before the inner code runs, it is not included
# * If your output is different than expected when using `range()` try checking your bounds

# %%
# range(1, 5) gives us 1, 2, 3, 4 NOT 5!
for value in range(1, 5):
    print(value)

# %%
# range() with one argument starts at 0
for value in range(5):
    print(value)

# %% [markdown]
# # Converting `range()` to a List
# ---
# * You can convert the results of `range()` directly into a list with the `list()` function
# * `range()` can also take a **third argument** as a step size to skip numbers

# %% [markdown]
# * If you want to make a list of numbers you can convert the results of `range()`
# * They can be directly converted into a list with the `list()` function
# * When you wrap `list()` around a call to the `range()` function it will output a list of numbers
# * We can also tell `range()` to skip numbers
# * If you give a third argument to `range()` Python uses that value as a step size
# * You can use this to do things like generating lists of even (or odd) numbers
# * In that code snippet the function starts with 2, then adds two at every increment
# * It does so until it reaches the end of the range
# * Suppose we want to make a list of the first 10 square numbers?

# %%
# Convert range to a list
numbers = list(range(1, 11))
print(numbers)

# %%
# Third argument is the step size  generate even numbers
even_numbers = list(range(2, 21, 2))
print(even_numbers)

# %% [markdown]
# # Building a List with a Loop
# ---
# Suppose you want to create a list of the first 10 square numbers
# We know how to make a list, square numbers, and set a range
#     * So, time to combine!

# %% [markdown]
# * You can create almost any set of numbers using `range()`
# * Suppose you want to create a list of the first 10 square numbers
# * We know how to make a list
# * We know how to square numbers
# * We know how to set a range
# * We started with an empty list called `squares`
# * Then we tell Python to loop through the first 10 numbers
# 	* The first 10 squares logically must be part of the squares of 1-10
# * Inside the loop we raise our current `value` to the power of two
# * We add our squared number to our `squares` list

# %%
squares = []

for value in range(1, 11):
    square = value ** 2
    squares.append(square)

print(squares)

# %% [markdown]
# # Simple Statistics with Lists
# ---
# A few Python functions are helpful when working with a list of numbers
# * `min()` — find the minimum value
# * `max()` — find the maximum value
# * `sum()` — add everything up

# %% [markdown]
# * A few Python functions are helpful when working with a list of numbers
# * For example, it is easy to find the:
# 	* Minimum `min()`
# 	* Maximum `max()`
# 	* Sum `sum()`

# %%
scores = [88, 74, 95, 62, 81, 90, 77]

print(f"Lowest score:  {min(scores)}")
print(f"Highest score: {max(scores)}")
print(f"Total points:  {sum(scores)}")

# %% [markdown]
# # List Comprehensions
# ---
# * A *list comprehension* generates the same list in **one line of code**
# * It combines the `for` loop and the creation of elements
# * More advanced Python but saves a lot of space!
# * Notice: **no colon** after the `for` loop inside the brackets

# %% [markdown]
# * The approach described earlier for generating squares required three or four lines of code
# * A *list comprehension* allows you to generate the same list in only a line of code
# * A *list comprehension* combines the `for` loop and the creation of elements
# * These are a more *advanced* level of Python
# * To use this syntax you must first begin with a descriptive name for a list
# * Next, you open a set of square brackets
# * Within those brackets you define the expression for the values you want to store
# * Here the expression is `value**2`
# * Then the loop is written, still within brackets
# * The for loop in this example is `for value in range(1,11)`
# * This feeds the values 1 through 10 into the expression `value**2`
# * Notice, there was no colon after this `for` loop
# * The result was the same as having the assignment within the loop codeblock

# %%
# The long way
squares = []
for value in range(1, 11):
    squares.append(value ** 2)
print(squares)

# The list comprehension way  same result, one line!
squares = [value ** 2 for value in range(1, 11)]
print(squares)

# %% [markdown]
# # Numerical Lists  Summary
# ---
# * `range(start, stop)` generates numbers upper bound is **exclusive**
# * `range(start, stop, step)` lets you skip numbers
# * `list(range(...))` converts range output to a list
# * `min()`, `max()`, `sum()` give quick stats on a list of numbers
# * List comprehensions generate lists in a single line: `[expression for item in range()]`
#
# Next up: **Slices, Copying, and Tuples**

# %% [markdown]
# That wraps up numerical lists and range. Key things to remember: range stops before the upper bound, list() converts it to a real list, and list comprehensions are a powerful shorthand. Next video we'll cover slices, copying lists, and tuples.
