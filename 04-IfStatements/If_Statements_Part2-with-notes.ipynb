# %% [markdown]
# <h1 style="text-align: center;">If Statements</h1>
# <h2 style="text-align: center;">Adapted from "Python Crash Course" By Eric Matthes</h2>

# %% [markdown]
# * Last video we learned how to write conditional tests
# * Now we put them to work in actual if statements
# * Several kinds of if statements exist — your choice depends on how many conditions you need to test

# %% [markdown]
# # Why this matters
# ---
# Programs need to behave differently depending on the situation
# * Show a different page to a logged-in user
# * Charge a different price based on membership
# * Send a different message depending on a score
#
# `if` statements are how your program **makes those decisions**

# %% [markdown]
# * When you understand conditional tests, you can start writing `if` statements
# * Several kinds of `if` statements exist
# * Your choice of which to use depends on the number of conditions needed to test
# * We've already seen if statements, but now it is time for a deeper dive

# %% [markdown]
# # Simple `if` Statements
# ---
# * The simplest `if` statement has **one test** and **one action**
# * If the conditional test evaluates to `True` → the indented block executes
# * If it evaluates to `False` → the block is ignored
# * Indentation plays the same role here as it does in `for` loops

# %% [markdown]
# * The simplest kinds of `if` statements only have one test and one action
# * You can put any conditional test in the first line
# * And just about any action in the indented block following the test
# * If the conditional test evaluates to `True` the code block is executed
# * If the conditional executes to `False` the code is ignored
# * Indentation plays the same role in `if` statements as it does in `for` loops
# * All indented lines after an `if` statement will be executed if the test passes
# * The entire block of indented items will be ignored if the test fails
# * You can have as many lines of code within the block as you need

# %%
age = 19

if age >= 18:
    print("You are old enough to vote!")
    print("Have you registered yet?")

# %% [markdown]
# # `if-else` Statements
# ---
# * Often you want to take one action when a condition passes, or another if it fails
# * The `else` block defines what happens when the test evaluates to `False`
# * Python will always execute **exactly one** of the two blocks

# %% [markdown]
# * Often you may want to take one action when a condition passes, or another if it fails
# * Python's `if-else` syntax makes this possible
# * An `if-else` block is similar to a simple `if` statement
# * The else allows you to define an action if the conditional test fails
# * If the condition passes the code in the first block runs
# * If the test evaluates to `False` the `else` block is executed
# * This code works because there are only two possible situations to evaluate
# * Python will always execute one of the two cases — only one of these two conditions will execute

# %%
age = 17

if age >= 18:
    print("You are old enough to vote!")
else:
    print("Sorry, you are too young to vote.")

# %% [markdown]
# # `if-elif-else` Chains
# ---
# * Often you need to test **more than two situations**
# * Python's `if-elif-else` syntax handles this
# * Python runs each conditional test **in order** until one passes
# * When a test passes, Python runs that block and **skips the rest**

# %% [markdown]
# * Often times you will need to test more than two situations
# * To evaluate these Python's `if-elif-else` syntax can be used
# * Python will execute only one block in the chain
# * It runs each conditional test in order, until one passes
# * When a test passes Python runs the code in its corresponding block, skipping the rest
# * Many real world situations involve multiple options
# * Consider a movie ticket that has a varying price based on age
# 	* Attendees under the age of four could be $2.00
# 	* 5-64 could be $12.00
# 	* And finally seniors 65 and over could be $7.00
# * The indented lines set the value of `price` based on age
# * After the price is set a separate `print()` is used to display the price
# * In addition to being more efficient, this revised code is easier to modify
# * To change the text of the message, you only have to alter one line

# %%
age = 12

if age < 4:
    price = 2
elif age < 18:
    price = 5
elif age < 65:
    price = 12
else:
    price = 7

print(f"Your admission price is ${price}.")

# %% [markdown]
# # Many `elif` Blocks
# ---
# * You can use **as many `elif` blocks** as you need
# * Python does **not require** an `else` at the end of an `if-elif` chain
# * Use `else` as a catch-all when you want a default
# * Use a final `elif` when you have a specific final condition to check

# %% [markdown]
# * You can use as many `elif` blocks in your code as needed
# * Python does not require an `else` block at the end of an `if-elif` chain
# * Sometimes an `else` is useful
# * Other times it may be clearer to use another `elif`
# * Or in yet another case you may simply not want a default option
# * The `else` block is a catch all statement, matching any condition that didn't match one of the checks
# * If you have a specific final condition use an `elif`
# * Otherwise, use an `else` if you want a catch all

# %%
age = 12

# Using a final elif instead of else — more explicit about what qualifies
if age < 4:
    price = 2
elif age < 18:
    price = 5
elif age < 65:
    price = 12
elif age >= 65:
    price = 7

print(f"Your admission price is ${price}.")

# %% [markdown]
# # Multiple Independent `if` Statements
# ---
# * `if-elif-else` stops as soon as one condition passes
# * Sometimes you need to check **all** conditions — more than one could be `True`
# * In that case use a **series of independent `if` statements**

# %% [markdown]
# * The `if-elif-else` chain is powerful, but it is only appropriate when you need one test to pass
# * As soon as one passing test is found, the rest are skipped
# * This behavior is beneficial because it's efficient and allows you to test for a specific condition
# * Sometimes it's important to check all conditions of interest
# * In this case a series of `if` statements can be used
# * This technique makes sense when more than one conditional could be `True`
# * If you want only one block to execute then you should use `if-elif-else`
# * If multiple blocks can execute then `if-if-if` can be used
# * When combining lists and `if` statements you can do some powerful things
# * You can watch for special values that need to be treated differently than other values
# * You can efficiently manage changing conditions
# * You can also begin to prove that your code works as you expect!

# %%
requested_toppings = ["mushrooms", "extra cheese", "pepperoni"]

# Each if is checked independently — multiple can be True
if "mushrooms" in requested_toppings:
    print("Adding mushrooms.")
if "pepperoni" in requested_toppings:
    print("Adding pepperoni.")
if "extra cheese" in requested_toppings:
    print("Adding extra cheese.")

print("\nFinished making your pizza!")

# %% [markdown]
# # Using `if` Statements with Lists
# ---
# * Combining lists and `if` statements is powerful
# * You can check for **special values** that need different treatment
# * You can check if a list is **empty** before trying to work with it
# * You can compare **two lists** against each other

# %% [markdown]
# * Now you hopefully have a basic understanding of conditional tests and `if` statements
# * That knowledge can be applied to look for special items in a list
# * Thus far our code has made a simple assumption — that the lists have at least one item
# * Remember some lists will start empty and will be built via user input
# * So, you can't always assume a list will have elements
# * There we start with an empty list
# * Prior to doing the loop we check to ensure there are elements in the list
# * And if there aren't we print out a message to that end
# * Can you think of another way to check if a list is empty?
# * Sometimes you will need to have multiple lists and make comparisons between the two
# * Suppose you work at a pizzeria and a customer is trying to add toppings to their pizza
# * You would have a pre-defined list of allowable toppings
# * And a list of their requested toppings
# * Then in the loop we checked to verify if each requested topping is available

# %%
# Checking for an empty list before looping
cities = []

if cities:
    for city in cities:
        print(f"Visiting {city}.")
else:
    print("No cities on the list yet!")

# %%
# Comparing two lists — checking requested toppings against available ones
available_toppings = ["mushrooms", "olives", "green peppers", "pepperoni", "pineapple"]
requested_toppings = ["mushrooms", "anchovies", "green peppers"]

for topping in requested_toppings:
    if topping in available_toppings:
        print(f"Adding {topping}.")
    else:
        print(f"Sorry, we don't have {topping}.")

# %% [markdown]
# # If Statements — Summary
# ---
# * Simple `if` — one test, one action
# * `if-else` — one action if True, another if False
# * `if-elif-else` — multiple conditions tested in order, **only one block runs**
# * Multiple `if` statements — **all conditions checked**, multiple blocks can run
# * Check for empty lists before looping: `if my_list:`
# * Compare two lists by looping through one and checking membership in the other
#
# Next week: **Dictionaries**!

# %% [markdown]
# That wraps up if statements. The key distinction to remember is if-elif-else stops at the first passing condition, while a series of independent if statements checks all of them. Next week we move on to dictionaries — a powerful way to store labeled data.
