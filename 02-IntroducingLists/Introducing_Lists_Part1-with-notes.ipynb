# %% [markdown]
# <h1 style="text-align: center;">Introducing Lists</h1>
# <h2 style="text-align: center;">Adapted from "Python Crash Course" By Eric Matthes</h2>

# %% [markdown]
# * We will start learning about lists, and how to start working with them
# * Lists allow you to store sets of information in one place
# * Lists can range from a few items to millions
# * One of the most powerful programming features
# * Tie together many important concepts

# %% [markdown]
# # Why this matters
# ---
# You rarely work with just one piece of data
# * A class roster
# * A list of search results
# * The scores in a game
#
# Lists are Python's way of keeping related data together so you can work with it as a group

# %% [markdown]
# * We will start learning about lists, and for to start working with them
# * Lists allow you to store sets of information in one place
# * Lists can range from a few items to millions
# * One of the most powerful programming features
# * Tie together many important concepts

# %% [markdown]
# # What is a List?
# ---
# * A collection of items in a particular order
# * Items don't have to be related
# * Usually contain multiple elements
# * Names are **plural** forms
#
# In Python **square brackets** `[]` indicate a list, items are separated by commas
#
# ![houses_named.png](houses_named.png)

# %% [markdown]
# * A collection of items in a particular order
# * The list can include:
# 	* The digits 0 to 9
# 	* The names of all the people in your family
# 	* Really anything you want
# * The items in a list don't have to be related
# * Lists usually contain more than one element so their names are the plural form of the word
# 	* letters, digits, names
# * In Python **square brackets** `[]` indicate a list
# * Individual items in a list are separated by commas

# %%
# A simple list of Wyoming cities
cities = ["Laramie", "Casper", "Cheyenne", "Sheridan", "Gillette"]
print(cities)

# %% [markdown]
# # Accessing Elements in a List
# ---
# * Lists are **ordered collections**
# * You can access any element by telling Python the **index** of the item
# * Write the list name followed by the index in square brackets
# * When you ask for a single item Python returns just that element — no brackets!

# %% [markdown]
# * Lists are ordered collections
# * You can access any element in a list by telling Python the position or *index*
# * To access an element you write the name of the list followed by the index of the item enclosed in square brackets
# * When you ask for a single item python will return just that
# * Notice it didn't include the brackets as the previous code did
# * It just returned the string element, so you can use the string methods we talked about earlier on it!

# %%
cities = ["Laramie", "Casper", "Cheyenne", "Sheridan", "Gillette"]

# Access the first city
print(cities[0])

# String methods work on list elements too!
print(cities[0].upper())

# Use in an f-string
print(f"The first city is {cities[0]}.")

# %% [markdown]
# # Index Positions Start at 0, Not 1
# ---
# * Python considers the **first item** to be at position `0`
# * This applies to most programming languages
# * If you have strange behavior in your code, check for an *off-by-one* error
# * Python has a special syntax for the **last element**: index `-1`
#
# ![numbered_houses.png](numbered_houses.png)

# %% [markdown]
# * You may have noticed that for our list we used `cities[0]` to get the first item
# * This is because Python considers the first item in a list to be at position `0`
# * This applies to most programming languages
# * If you have strange behavior in your code, check to see if you're making a simple but common *off-by-one* error
# * The second item in a list has an index of 1
# * Using this counting method you can get any element you want from a list by subtracting one from its position in the list
# * To get the 4th item you use index 3, etc.
# * Python has a special syntax for when you wish to access the last element in an array: `-1`
# * The syntax can be quite useful — this enables you to access the last element without needing to know how long the array is
# * This convention extends to other negative index values
# * `-2` will return the second to last element, `-3` returns the third to last

# %%
cities = ["Laramie", "Casper", "Cheyenne", "Sheridan", "Gillette"]

print(cities[0])   # first item
print(cities[1])   # second item
print(cities[-1])  # last item — always works regardless of list length
print(cities[-2])  # second to last
# Out:
# Laramie
# Casper
# Gillette
# Sheridan

# %% [markdown]
# # Index Errors
# ---
# Asking for an index that doesn't exist gives you an `IndexError`
# Let's trigger one intentionally so you know what it looks like!

# %% [markdown]
# * There is one type of error that's common when working with lists
# * Let's assume you have a list with four cities and try to access the city at index position 4
# * Python attempts to give you the item at index four
# * But, when it searches the list there are no items with that index
# * Because of the *off-by-one* nature of indexing in lists, this error is typical
# * People think the third item is number 3, as they start counting at 1
# * But, the third item is really 2
# * An index error means Python can't find an item at the index requested
# * If you encounter an index error, try adjusting your count by `-1`
# * Remember, when you want to access the last item in a list you can use `cities[-1]`

# %%
cities = ["Laramie", "Casper", "Cheyenne", "Sheridan", "Gillette"]

# This list has 5 items (indices 0-4) — index 5 doesn't exist!
print(cities[5])

# %%
# Fix: use -1 to always safely get the last item
print(cities[-1])

# %% [markdown]
# # Using Individual Values from a List
# ---
# You can use an individual value from a list just as you would any other variable
# f-strings work great with list elements!

# %% [markdown]
# * You can use an individual value from a list as you would a variable
# * You can even assign it to a variable, but you don't need to — it's already stored!
# * f-strings can be used to create a message based on a value from the list

# %%
cities = ["Laramie", "Casper", "Cheyenne", "Sheridan", "Gillette"]

# Use a list element directly in an f-string
print(f"I live in {cities[0]}.")
print(f"The last city in our list is {cities[-1]}.")

# Can also assign to a variable first
my_city = cities[2]
print(f"My city is {my_city}.")

# %% [markdown]
# # Lists Part 1 — Summary
# ---
# * A **list** is a collection of items in a particular order, defined with `[]`
# * List names are **plural** by convention
# * Access elements using their **index** — starting at `0`, not `1`
# * Use `-1` to always get the last item regardless of list length
# * Asking for an index that doesn't exist gives an `IndexError`
# * Individual list elements work just like variables — f-strings, methods, etc.
#
# Next up: **Modifying Lists and Organizing**

# %% [markdown]
# That wraps up the first part of Introducing Lists. We covered what a list is, how to access elements by index, the off-by-one nature of indexing, and how to use list elements like variables. Next video we'll look at how to modify, add, remove, and organize list elements.
